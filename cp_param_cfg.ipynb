# %%
import json

best_key_dict = {
    "backbone": [
        "segswin-base",
        "segswin-small"
    ],
    "mfusion": "LSF",
    "warmup_epoch": 40,
    "max_epoch": 100,
    "lr": 3e-4,
    "clip": 0.8,
    "train_batch": 32,
    "decay_epoch": 10,
    "gamma": 0.5,
    "texture": "/namlab40/",
}

best_key_cfg = {
    "RGB_SEG_SWIN":[128,256,512,1024],
    "X_SEG_SWIN":[96,192,384,768]
}
